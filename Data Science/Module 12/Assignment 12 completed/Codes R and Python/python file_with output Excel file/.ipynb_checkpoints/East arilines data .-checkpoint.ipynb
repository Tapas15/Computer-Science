# %% [markdown]
# # Hirarchy East airline data

# %% [markdown]
# # Data Pre Processing

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
# data preprocessing ,cleaning and primary visualization
mydata = pd.read_csv("D:\\R and python practice\\Module 12\\Assignment\\EastWestAirlines.xlsx\\EastWestAirlinesClusterCSV.csv",index_col=0)
mydata.head() # we imported data by setting index column to 0 before 
# the data on right side is problmatic lets shift column to row 
#univ.describe() # data are not normal  as we can seet it
# Out:
#      Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1      28143           0          1          1          1          174
# 2      19244           0          1          1          1          215
# 3      41354           0          1          1          1         4123
# 4      14776           0          1          1          1          500
# 5      97752           0          4          1          1        43300
#
#      Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1              1                  0                0               7000
# 2              2                  0                0               6968
# 3              4                  0                0               7034
# 4              1                  0                0               6952
# 5             26               2077                4               6935
#
#      Award?
# ID#
# 1         0
# 2         0
# 3         0
# 4         0
# 5         1

# %%
mydata.describe() # just checking the data
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
mydata.shape # sizw of mydata # problem removing column or row dat so imputed with mean value row and column
# Out:
# (3999, 11)

# %% [markdown]
# # Cleaning of data

# %%
import numpy as np
# replace "?" to NaN
mydata.replace("?", np.nan, inplace = True) # if any value is left with blank we replae it with nan value 
mydata.head() # it seems there is no nan value
# Out:
#      Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1      28143           0          1          1          1          174
# 2      19244           0          1          1          1          215
# 3      41354           0          1          1          1         4123
# 4      14776           0          1          1          1          500
# 5      97752           0          4          1          1        43300
#
#      Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1              1                  0                0               7000
# 2              2                  0                0               6968
# 3              4                  0                0               7034
# 4              1                  0                0               6952
# 5             26               2077                4               6935
#
#      Award?
# ID#
# 1         0
# 2         0
# 3         0
# 4         0
# 5         1

# %%
mydata.dropna() # we are droping na value if na is not cleared it willdrop na value and will give cleaned data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# ...

# %%
mydata.isnull() # it means there is no missing data in cells
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1       False       False      False      False      False        False
# 2       False       False      False      False      False        False
# 3       False       False      False      False      False        False
# 4       False       False      False      False      False        False
# 5       False       False      False      False      False        False
# ...       ...         ...        ...        ...        ...          ...
# 4017    False       False      False      False      False        False
# 4018    False       False      False      False      False        False
# 4019    False       False      False      False      False        False
# 4020    False       False      False      False      False        False
# 4021    False       False      False      False      False        False
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# ...

# %%
mydata.notnull() # null value is not present , all cell value are filled
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1        True        True       True       True       True         True
# 2        True        True       True       True       True         True
# 3        True        True       True       True       True         True
# 4        True        True       True       True       True         True
# 5        True        True       True       True       True         True
# ...       ...         ...        ...        ...        ...          ...
# 4017     True        True       True       True       True         True
# 4018     True        True       True       True       True         True
# 4019     True        True       True       True       True         True
# 4020     True        True       True       True       True         True
# 4021     True        True       True       True       True         True
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# ...

# %% [markdown]
# # Exploratory data annalysis

# %%
mydata.plot.hist() 
# blue explains murder, and red expains rape cases are very frequent

# %%
mydata.plot.line() # line plot description of each variable

# %%
mydata.plot.box() # box plot visualization

# %%
mydata.plot.area() # ploting we can see the viaualization

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(mydata, alpha=0.2, figsize=(6, 6), diagonal='kde') # scattar matrix visualization of data
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000259CB3292C8>,
# ...
#       dtype=object)

# %%
mydata.plot.kde() # single kde visualization

# %%
# Plot with Color in function of the cluster
import seaborn as sns
# Plot with Color in function of the cluster
corrmat = mydata.corr()
f, ax = plt.subplots(figsize =(9, 8)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
sns.pairplot(mydata) # we can check the relationship corelation exist of othe variable

# %%
sns.barplot(data=mydata) # bar explains the expenses as compared to sat scores

# %%
mydata.plot(subplots=True, figsize=(6, 6)); # checking subplot of each line
# how each line variable varried and realtede clearly visible with some of university similarity view

# %%
mydata.plot(colormap='cubehelix')

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())	/	(i.max()	-	i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(mydata.iloc[:,1:])
df_norm.head() # running noramalization function of data set
# Out:
#      Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# ID#
# 1           0.0       0.00        0.0        0.0     0.000660     0.011628
# 2           0.0       0.00        0.0        0.0     0.000815     0.023256
# 3           0.0       0.00        0.0        0.0     0.015636     0.046512
# 4           0.0       0.00        0.0        0.0     0.001896     0.011628
# 5           0.0       0.75        0.0        0.0     0.164211     0.302326
#
#      Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# ID#
# 1             0.000000         0.000000           0.843742     0.0
# 2             0.000000         0.000000           0.839884     0.0
# 3             0.000000         0.000000           0.847842     0.0
# 4             0.000000         0.000000           0.837955     0.0
# 5             0.067398         0.075472           0.835905     1.0

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch # for creating dendrogram

# %%
type(df_norm)
z = linkage(df_norm, method="complete",metric="euclidean")

# %% [markdown]
# # Model building

# %%
plt.figure(figsize=(15, 5));plt.title('Hierarchical Clustering Dendrogram');plt.xlabel('Index');plt.ylabel('Distance')
sch.dendrogram(
    z,
    leaf_rotation=0.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
z1 = linkage(df_norm, method="ward",metric="euclidean")

# %%
plt.figure(figsize=(15, 5));plt.title('Hierarchical Clustering Dendrogram');plt.xlabel('Index');plt.ylabel('Distance')
sch.dendrogram(
    z1,
    leaf_rotation=0.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
# Now applying AgglomerativeClustering choosing 3 as clusters from the dendrogram
from	sklearn.cluster	import	AgglomerativeClustering 
h_complete	=	AgglomerativeClustering(n_clusters=3,	linkage='ward',affinity = "euclidean").fit(df_norm)

# %%
cluster_labels=pd.Series(h_complete.labels_)
mydata['clust']=cluster_labels # creating a  new column and assigning it to new column 
#mydata = mydata.iloc[:,[8,7,0,1,2,3,4,5,6]]
#univ
mydata.head()
# Out:
#      Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1      28143           0          1          1          1          174
# 2      19244           0          1          1          1          215
# 3      41354           0          1          1          1         4123
# 4      14776           0          1          1          1          500
# 5      97752           0          4          1          1        43300
#
#      Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1              1                  0                0               7000
# 2              2                  0                0               6968
# 3              4                  0                0               7034
# 4              1                  0                0               6952
# 5             26               2077                4               6935
#
#      Award?  clust
# ID#
# 1         0    1.0
# 2         0    1.0
# 3         0    1.0
# ...

# %%
# getting aggregate mean of each cluster
#mydata =mydata.iloc[:,-12::]  
#mydata.head()

# %%
#mydata.rename( columns={'Unnamed: 0':'States'}, inplace=True ) # there is no un named column exist in this data set

# %%
#mydata.head() # calling head of data

# %%
# last imported cluster it now makint it to first columns 
cols = list(mydata.columns) # broughe last cluster column to first 
cols = [cols[-1]] + cols[:-1]
mydata = mydata[cols]

# %%
mydata.head() # im trying to remove the index number some where im lackin i will do it later on after finding out
# Out:
#      clust  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1      1.0    28143           0          1          1          1          174
# 2      1.0    19244           0          1          1          1          215
# 3      1.0    41354           0          1          1          1         4123
# 4      0.0    14776           0          1          1          1          500
# 5      1.0    97752           0          4          1          1        43300
#
#      Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1              1                  0                0               7000
# 2              2                  0                0               6968
# 3              4                  0                0               7034
# 4              1                  0                0               6952
# 5             26               2077                4               6935
#
#      Award?
# ID#
# 1         0
# 2         0
# ...

# %%
# creating a csv file 
mydata.to_csv("East_Airlines_final1.csv",encoding="utf-8")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Home\\Desktop\\Workspace for jupiter\\python file'
