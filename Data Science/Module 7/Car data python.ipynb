# %% [markdown]
# # Assignment modue no 7  In python

# %% [markdown]
#  CAR Data Cleaning and practicing

# %% [markdown]
# Description of dataset:- sourcing information is silent , dont know whrere is data came form, we hopind a imaginary car dataset,as It is a Car dataset we are more intrested into looking into MPG:- milage per gallon of dataset for gaining more and more inforamation out of it.

# %%
import pandas as pd

# %%
df = pd.read_csv('Cars.csv') #  attribut4e

# %%
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %% [markdown]
# What is menaing of meaning of data that shoud be understood first HP - Engine Horse power , MPG- Milage per galloon(Average miles per gallon) , VOL -Cubic feet of cab space , SP- Speed per hour , Wt - Weight of the vehicle
#
# But those data does not represent the vehicle items or car names From which the data came from , I am just taking each observation of index no 1 to 81 as like Numbers of Cars in this dataset.

# %%
df.describe()# by using this we can able to see the overview of particular data types
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %% [markdown]
# ### Playing with attributes

# %%
df.var() # values varies form the mean by
# Out:
# HP     3261.952160
# MPG      83.383283
# VOL     497.356790
# SP      201.113002
# WT       56.142247
# dtype: float64

# %%
df.info() # our structure of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
print(df)
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
df.isnull() # there is no null value
# Out:
#        HP    MPG    VOL     SP     WT
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# ..    ...    ...    ...    ...    ...
# 76  False  False  False  False  False
# 77  False  False  False  False  False
# 78  False  False  False  False  False
# 79  False  False  False  False  False
# 80  False  False  False  False  False
#
# [81 rows x 5 columns]

# %%
df.isna().sum() # no na value as we can see no missing value present in our data
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %% [markdown]
# some how i will findout intrepareation of different data in order to understand its feature i need to see its different corleantio point of each data types and correlaiion of each coulumns lets get numeric value of each column

# %%
df.corr() # finding the cor relation of each point to extract the features of the data
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(df) # we suppose to check correaltion of each variavle with different variable in data set

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(df, kind="scatter", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %% [markdown]
# lsets see distribution of variable of in a boxplot

# %%
sns.boxenplot(df) # it shows how data is spread across the box plot

# %% [markdown]
# the information or the distrubution of data can be seen from 40 to 120 of data demarketed above

# %%
sns.distplot(df) # it shows the distribution of the data

# %%
sns.distplot(df['MPG'])  # we can see the distribution of the mpg

# %%
sns.distplot(df['VOL'])

# %%
sns.distplot(df['WT'])

# %% [markdown]
# From the above distribution we can see that how it is matching with each other as if thery are same volumen and weight

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(df.corr(),annot=True) # checking correlation of each number

# %% [markdown]
# From the above hp is corelated it can be seen that hp has co realtion with manry variable above and MPG is negatively correlated
# and vol ,sp ,weight some how negatively correalted , and sp shows high digreee of positive correaltion

# %%
df.columns # viewing the columns indicating our data frame
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
X = df[['HP', 'VOL', 'SP', 'WT']] # my feature variable

# %%
Y = df[['MPG']] # my target variabe

# %% [markdown]
# Befoe Doing Train test split we will check data for normality

# %%
import scipy.stats as stats # import scipy model and pylab for qqline and qqplot in python 
import pylab

# %% [markdown]
# Lets Check each Variable  normality

# %%
stats.probplot(df.HP,dist ="norm",plot =pylab)
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %% [markdown]
# HP it is not normally distributes clearly visible as we can see the data points

# %%
stats.probplot(df.MPG,dist ="norm",plot = pylab)
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %% [markdown]
# AS we can see the probablity point of this data is normally distributed

# %%
stats.probplot(df.VOL, dist = "norm", plot = pylab)
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %% [markdown]
# we can see the distribution of the points on the line as it seems not normal

# %%
stats.probplot(df.SP, dist = "norm",plot = pylab)
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %% [markdown]
# as we can see the points it seems normal but not a normal

# %%
stats.probplot(df.WT,dist ="norm",plot =pylab)
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %% [markdown]
# it is also not a normal as looks like

# %%
sns.scatterplot(x='HP',y='MPG',data=df) # lets do some scatterplot

# %%
sns.scatterplot(x='MPG',y='VOL',data=df)

# %%
sns.scatterplot(x='VOL',y='SP',data=df)

# %%
sns.scatterplot(x='SP',y='WT',data=df)

# %%
sns.boxplot(df) # box plot suggesting outliers but we will find each data outliers lets see seach

# %%
sns.boxplot(df['HP']) # Hp already seend multiple outlers

# %%
sns.boxplot(df['MPG']) # no outliers seems

# %%
sns.boxplot(df['VOL']) # two outliers point in respective side

# %%
sns.boxplot(df['SP'])  # outliers

# %%
sns.boxplot(df['WT']) # outliers

# %%
import seaborn as sns; sns.set()

# %%
import matplotlib.pyplot as plt

# %%
ax = sns.scatterplot(x="MPG", y="HP", data=df)

# %% [markdown]
# # Creating Statistical models

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols('MPG~WT+VOL+SP+HP',data=df).fit()

# %%
model.conf_int # stats model coffient
# Out:
# <bound method RegressionResults.conf_int of <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001EC86905C88>>

# %%
print(model.summary()) # summary of the model
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     63.80
# Date:                Sun, 19 Jul 2020   Prob (F-statistic):           1.54e-23
# Time:                        19:10:08   Log-Likelihood:                -233.96
# No. Observations:                  81   AIC:                             477.9
# Df Residuals:                      76   BIC:                             489.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.6773     14.900      2.059      0.043       1.001      60.354
# ...

# %%
model.summary2 # short status summary of our model
# Out:
# <bound method RegressionResults.summary2 of <statsmodels.regression.linear_model.OLSResults object at 0x000001EC8691F988>>

# %%
model.fittedvalues # fitted values
# Out:
# 0     43.441935
# 1     42.388793
# 2     42.279341
# 3     42.538360
# 4     42.172648
#         ...
# 76    21.282096
# 77    17.899050
# 78    26.136453
# 79    12.316612
# 80    15.559481
# Length: 81, dtype: float64

# %% [markdown]
# Calculating VIF model of influence of data

# %%
# %matplotlib inline

# %%
from statsmodels.compat import lzip
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(model, ax=ax, criterion="cooks")

# %%
influence = model.get_influence()

# %%
from statsmodels.graphics.regressionplots import *

# %%
(c, p) = influence.cooks_distance
plt.stem(np.arange(len(c)), c, markerfmt=",")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
plot_leverage_resid2(model)

# %%
influence_plot(model)

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df))

# %%
threshold = 4
print(np.where(z > 3)) # we dignosed our outliers
# Out:
# (array([70, 76, 76, 79, 79], dtype=int64), array([3, 0, 3, 0, 3], dtype=int64))

# %%
print(z[70]) # through this we can find out the pointing variation
# Out:
# [2.86348272 1.62465312 2.20026792 3.05515833 2.22785207]

# %%
print(z[76])# for 76 also
# Out:
# [3.60344233 0.27305243 2.20026792 3.40992879 2.18623649]

# %%
print(z[79])# for 79 also
# Out:
# [3.12775401 1.60754809 0.91297193 3.292567   0.94146241]

# %%
print(z[70][1])
# Out:
# 1.624653122908629

# %%
print(z[76][1])
# Out:
# 0.27305243311314065

# %%
print(z[79][1])
# Out:
# 1.6075480888892086

# %% [markdown]
# But we are chooseing 76 as outlier outside variable as it is seen

# %%
model1 = smf.ols('MPG~WT+VOL+SP+HP',data=df).fit()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
df.dtypes
# Out:
# HP       int64
# MPG    float64
# VOL      int64
# SP     float64
# WT     float64
# dtype: object

# %%
import numpy as np

# %% [markdown]
# df.drop([df.index[76]]) # i dropped the value index 76 as it is the outlier

# %%
model2 = smf.ols('MPG~WT+VOL+SP+HP',data=df.drop([df.index[76]])).fit() # dropped the 76 item in our

# %%
print(model2.summary()) # after removing the out
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     84.96
# Date:                Sun, 19 Jul 2020   Prob (F-statistic):           4.42e-27
# Time:                        19:10:40   Log-Likelihood:                -222.00
# No. Observations:                  80   AIC:                             454.0
# Df Residuals:                      75   BIC:                             465.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     27.8268     13.323      2.089      0.040       1.287      54.367
# ...

# %%
df.columns # viewing the columns indicating our data frame
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
X = df[['HP', 'VOL', 'SP', 'WT']] # my feature variable

# %%
y = df[['MPG']] # my y variable  same can be do as well as you like

# %% [markdown]
# ## Checking influencing Variable from our model and delete that variaable from our sklearn

# %%
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
rsquared_hp =  smf.ols('HP~WT+VOL+SP',data=df).fit().rsquared # calculating rsquared to closely measure
vif_hp = 1/(1-rsquared_hp) #19.92658897499852 
vif_hp # we got the variable influencing factior in HP variable
# Out:
# 19.92658897499852

# %%
rsquared_wt = smf.ols('WT~HP+VOL+SP',data=df).fit().rsquared  
vif_wt = 1/(1-rsquared_wt) # 639.5338175572624
vif_wt
# Out:
# 639.5338175572624

# %%
rsqared_vol = smf.ols('VOL~WT+SP+HP',data=df).fit().rsquared  
vif_vol = 1/(1-rsqared_vol) #  638.8060836592878
vif_vol
# Out:
# 638.8060836592878

# %%
rsqared_sp = smf.ols('SP~WT+VOL+HP',data=df).fit().rsquared  
vif_sp = 1/(1-rsqared_sp) #  20.007638783050126
vif_sp
# Out:
# 20.007638783050126

# %% [markdown]
#  Storing vif values in a data frame

# %%
d1 = {'Variables':['Hp','WT','VOL','SP'],'VIF':[vif_hp,vif_wt,vif_vol,vif_sp]}

# %%
Vif_frame = pd.DataFrame(d1)

# %%
Vif_frame
# Out:
#   Variables         VIF
# 0        Hp   19.926589
# 1        WT  639.533818
# 2       VOL  638.806084
# 3        SP   20.007639

# %% [markdown]
# Added Variable plot to choose correct model out of it

# %%
sm.graphics.plot_partregress_grid(model2) # model after droppint 76 item from data frame

# %% [markdown]
# Feature selection model is not present in stats model so we will use sklean model for feature selection here we have to choose manually and take out the variable out here we see weight having more VIF so we removing it 	639.533818

# %%
# final model
final_ml= smf.ols('MPG~VOL+SP+HP',data =df.drop([df.index[76]])).fit()
final_ml

# %%
print(final_ml.summary()) # Rsquared value is 81% its a good model
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     114.8
# Date:                Sun, 19 Jul 2020   Prob (F-statistic):           3.78e-28
# Time:                        20:42:54   Log-Likelihood:                -222.00
# No. Observations:                  80   AIC:                             452.0
# Df Residuals:                      76   BIC:                             461.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     27.7555     12.922      2.148      0.035       2.018      53.493
# ...

# %% [markdown]
# ## Lets do it by sklearn Spliting our data training and test

# %%
df1 = df.loc[76]
df1 = df.drop([df.index[76]])
df1 # 76 the item is removed
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 75  175  18.762837  129  132.864163  42.778219
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [80 rows x 5 columns]

# %%
df1.columns # viewing the columns indicating our data frame
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
X = df1[['HP', 'VOL', 'SP', 'WT']] # my feature variable

# %%
Y = df1[['MPG']] # my target variabe

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.4,random_state=101)

# %% [markdown]
# # Creating and training the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Model Evaluation again

# %%
#print the intercept
print(lm.intercept_)
# Out:
# [39.40075023]

# %%
lm.coef_ # cofficient of our model
# Out:
# array([[-0.19660245,  0.09708058,  0.29981927, -0.87615408]])

# %% [markdown]
# ## Prediction of our model

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(Y_test,predictions)

# %%
sns.distplot((Y_test-predictions),bins=50)

# %% [markdown]
# # Feature selection model

# %%
from sklearn.feature_selection import RFE

# %%
lm = LinearRegression()

# %%
rfe = RFE(lm, 3)

# %%
rfe = rfe.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(rfe.support_)
# Out:
# [ True  True  True False]

# %%
print(rfe.ranking_)
# Out:
# [1 1 1 2]

# %%
X # From above rfe Ranking we Dropping feature Weight as below it is not required in our model
# Out:
#      HP  VOL          SP         WT
# 0    49   89  104.185353  28.762059
# 1    55   92  105.461264  30.466833
# 2    55   92  105.461264  30.193597
# 3    70   92  113.461264  30.632114
# 4    53   92  104.461264  29.889149
# ..  ...  ...         ...        ...
# 75  175  129  132.864163  42.778219
# 77  238  115  150.576579  37.923113
# 78  263   50  151.598513  15.769625
# 79  295  119  167.944460  39.423099
# 80  236  107  139.840817  34.948615
#
# [80 rows x 4 columns]

# %% [markdown]
# # Again making and evaulating model

# %%
x= df1[['HP', 'VOL', 'SP',]]

# %%
x
# Out:
#      HP  VOL          SP
# 0    49   89  104.185353
# 1    55   92  105.461264
# 2    55   92  105.461264
# 3    70   92  113.461264
# 4    53   92  104.461264
# ..  ...  ...         ...
# 75  175  129  132.864163
# 77  238  115  150.576579
# 78  263   50  151.598513
# 79  295  119  167.944460
# 80  236  107  139.840817
#
# [80 rows x 3 columns]

# %%
lm1 = LinearRegression()

# %%
lm1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, Y_train, Y_test = train_test_split(x,Y,test_size = 0.4,random_state=101)

# %%
lm1.fit(x_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm1.intercept_)
# Out:
# [41.11018054]

# %%
print(lm1.coef_)
# Out:
# [[-0.19309932 -0.19787556  0.28832068]]

# %% [markdown]
# # Prediction of our model

# %%
pred = lm1.predict(x_test)

# %%
plt.scatter(Y_test,pred)

# %%
sns.distplot((Y_test-pred),bins=50)

# %%
final_linear_model = lm1  # our final model evaulated

# %% [markdown]
# # Lets Evaulates our Regression metrices

# %% [markdown]
# We can see our regression model in terms of errors in the model

# %%
from sklearn import metrics

# %%
print('MAE:',metrics.mean_absolute_error(Y_test,pred))
# Out:
# MAE: 3.321438247174835

# %%
print('MSE:', metrics.mean_squared_error(Y_test, pred))
# Out:
# MSE: 18.835182601304567

# %%
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, pred)))
# Out:
# RMSE: 4.339951912326284

# %%
final_linear_model = lm1  # our final model evaulated

# %%
lm1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
