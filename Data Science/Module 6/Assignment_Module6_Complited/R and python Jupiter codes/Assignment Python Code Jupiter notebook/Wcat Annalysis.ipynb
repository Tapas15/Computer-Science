# %%
import pandas as pd # for manupulationg of file

# %%
wcat = pd.read_csv("D:\R and python practice\Module 6\Study material\wc-at.csv\wc-at.csv")
wcat
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ###############################Data pre procesing and Cleaning#######################

# %%
plt.boxplot(wcat) # many boxplot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e2e9d268c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e2e9d319c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e2e9d07dc8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1e2e9d35ac8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1e2e9d35bc8>,
# ...
#  'means': []}

# %%
plt.boxplot(wcat.Waist)# no outliers
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e2ea7fdfc8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e2ea800ac8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e2ea7fd788>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e2ea822b88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e2ea824b88>],
#  'means': []}

# %%
plt.boxplot(wcat.AT)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e2ea7ce748>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e2eb812d48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e2eb80e388>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e2eb816cc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e2eb816dc8>],
#  'means': []}

# %%
wcat.shape
# Out:
# (109, 2)

# %%
wcat.describe
# Out:
# <bound method NDFrame.describe of       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]>

# %%
wcat.info
# Out:
# <bound method DataFrame.info of       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]>

# %% [markdown]
# #####################Exploratory DATA Annalyis##################################

# %%
# Univariate annalysis 
wcat.info() # number of columns and rows index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
# Waist    109 non-null float64
# AT       109 non-null float64
# dtypes: float64(2)
# memory usage: 1.8 KB

# %%
#mean
wcat.Waist.mean() # Waist returning mean 91.90183486238533
# Out:
# 91.90183486238533

# %%
wcat.AT.mean() #AT returning mean 101.89403669724771
# Out:
# 101.89403669724771

# %%
#median
wcat.Waist.median()# median is 90.8
# Out:
# 90.8

# %%
wcat.AT.median()#  96.54
# Out:
# 96.54

# %%
# mode exists
wcat.Waist.mode() # mode  0     94.5 ,1    106.0 ,2    108.5
# Out:
# 0     94.5
# 1    106.0
# 2    108.5
# dtype: float64

# %%
wcat.AT.mode() # mode  0    121.0 ,1    123.0
# Out:
# 0    121.0
# 1    123.0
# dtype: float64

# %%
# Basic Bar plot 
plt.bar(x= wcat["Waist"],height = wcat["AT"]) # barplot visualization x and y as height
# Out:
# <BarContainer object of 109 artists>

# %%
plt.bar(x= wcat["AT"],height = wcat["Waist"]) # barplot visualization y and x as height
# Out:
# <BarContainer object of 109 artists>

# %%
# Basic barplot understandig data increasing viaualization 
plt.bar(x= wcat["Waist"],height = wcat["Waist"]) # barplot visualization x column increasing order
# Out:
# <BarContainer object of 109 artists>

# %%
plt.bar(x= wcat["AT"],height = wcat["AT"]) # barplot visualization x and y as height
# Out:
# <BarContainer object of 109 artists>

# %%
# Basic line plot bi variate annalysis
wcat.plot.line(x='Waist',y = 'AT', figsize=(8,6)) # line plot x and y data visualization

# %%
wcat.plot.line(x='AT',y = 'Waist', figsize=(8,6)) # line plot y and x data visualization

# %%
#Scattar plot to see each sided data visualization bi-variate in uni
wcat.plot.scatter(x='Waist',y = 'AT', figsize=(8,6)) # Scatter plot x and y data visualization

# %%
wcat.plot.scatter(x='AT',y = 'Waist',figsize =(8,6)) # Scatter plot y and x Data visualization

# %%
#Basic Box plot to see the data visualization 
wcat.plot.box(figsize=(10,8)) # Waist wiscer is small and AT wiscer it too long there is no outliers

# %%
# Basic Density plot normal visuality
wcat['Waist'].plot.kde() # to see how data is distributed in normal view in each column

# %%
wcat['AT'].plot.kde() # to see how data is distributed like as normal distribution

# %%
# histogram annalysis 
wcat['Waist'].hist() # visualising histogram of waist data

# %%
wcat['AT'].hist() # we can have ide about how data is spread

# %%
wcat['Waist'].plot(kind ='hist',bins =20) # bin size reduced visualization

# %%
wcat['AT'].plot(kind ='hist',bins =20)

# %%
#Bi-Variate annalysis of data 
wcat.plot.area() # as we can visualize each area wise data how it is spread

# %%
wcat.plot.line()# line spread of data visualization

# %%
wcat.plot.scatter(x='Waist',y ='AT') # simple scattar digram visualization

# %%
wcat.plot.bar() # simple bar plot simple togeather barplot visualization

# %%
wcat.plot.bar(stacked =True)# simple barplot with stacked data # stacked barplot vsualization

# %%
wcat.plot.box()# simple boxplot visualization

# %%
#Hexagon intersection plot to see more data point joints bi variate annalysis
wcat.plot.hexbin(x='Waist', y='AT', gridsize=30, figsize=(8,6)) # intersecting point is more darker

# %%
wcat.plot.hexbin(x='AT', y='Waist', gridsize=30, figsize=(8,6)) # intersecting point is more darker

# %%
#Bi-variate histogram annalysis 
""" Histogram Bi-plot annalys prelim """
#fig =plt.figure(figsize=(1,1))  # histogram to visualize data to see
ax1 =fig.add_subplot(121) # it looks like unit b value is more as compared to a
#ax1.set_xlabel("Waist")
#ax1.set_ylabel("AT")
ax1.set_title("wcat")
wcat.plot(kind="hist")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-1bfe3ebead3a> in <module>
#       2 """ Histogram Bi-plot annalys prelim """
#       3 #fig =plt.figure(figsize=(1,1))  # histogram to visualize data to see
# ----> 4 ax1 =fig.add_subplot(121) # it looks like unit b value is more as compared to a
#       5 #ax1.set_xlabel("Waist")
#       6 #ax1.set_ylabel("AT")
#
# NameError: name 'fig' is not defined

# %%
#############################Normality and Hypothesis checking########################3
import scipy.stats as stats
import pylab
# checking normality using line qqline ,qqplot of disttribution of data 
stats.probplot(wcat.Waist,dist ="norm",plot = pylab) # Data differs from normality

# %%
stats.probplot(wcat.AT,dist ="norm",plot =pylab,rvalue =True) # Data is not normal

# %%
#Now Data Normality check  shapiro test

print(stats.shapiro(wcat.Waist)) # Data is not normal
print(stats.shapiro(wcat.AT)) # same is here data is not normal
help(stats.shapiro)
""" Data is not normal in both cases as it is below p value is less from above test 
hence it could be rejected .....in future annalysis i will learn a lot more how to transforem data into normal
after tranforming and learning how to make it as normal then carr out my obervation"""

# %%
############################## Model Buiding############################################ 
import numpy as np
#import statsmodels.api as sm
import statsmodels.formula.api as smf
from plotnine import *
(ggplot(wcat,aes("Waist","AT"))+geom_point())+stat_smooth(method = 'lm') # Scattarplot and with abline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (-9223371907207224372)>

# %%
##### MODEL BUILDING ########
#model 1 
plt.scatter(x=wcat['Waist'], y=wcat['AT'],color='green')# Scatter plot
np.corrcoef(wcat.Waist, wcat.AT) #correlation
mod = smf.ols('AT ~ Waist', data=wcat).fit()
mod.summary() # to see the summary of out model

pred1 = mod.predict(pd.DataFrame(wcat['Waist'])) # model prediction 
pred1
#printing level of interval for confidence
print (mod.conf_int(0.01)) # 99% confidence interval
# residuals
res = wcat.AT - pred1
res
#rmse
sqres = res*res
mse = np.mean(sqres)
rmse = np.sqrt(mse)
rmse
# Out:
#                     0           1
# Intercept -273.143516 -158.819460
# Waist        2.843470    4.074248
# 32.760177495755144

# %%
######### Model building on Transformed Data

# Log Transformation
# x = log(waist); y = at
plt.scatter(x=np.log(wcat['Waist']),y=wcat['AT'],color='brown')
np.corrcoef(np.log(wcat.Waist), wcat.AT) #correlation
# linear model 2 
model2 = smf.ols('AT ~ np.log(Waist)',data=wcat).fit()
model2.summary()
# prediction
pred2 = model2.predict(pd.DataFrame(wcat['Waist']))
pred2
# printing inter val level of confidence 
print(model2.conf_int(0.01)) # 99% confidence level
# residuals
res2 = wcat.AT - pred2
res2
# rmse of second model
sqres2 = res2*res2
mse2 = np.mean(sqres2)
rmse2 = np.sqrt(mse2)
rmse2
# Out:
#                          0            1
# Intercept     -1579.905632 -1076.778346
# np.log(Waist)   261.384641   372.886487
# 32.496884909321274

# %%
pred2 = model2.predict(pd.DataFrame(wcat['Waist']))
pred2
# Out:
# 0       39.828156
# 1       30.572779
# 2       68.410960
# 3       76.638769
# 4       39.403610
#           ...
# 104    132.438233
# 105    110.127880
# 106    137.778929
# 107    156.234559
# 108    157.993171
# Length: 109, dtype: float64

# %%
# Exponential transformation
plt.scatter(x=wcat['Waist'], y=np.log(wcat['AT']),color='orange')

np.corrcoef(wcat.Waist, np.log(wcat.AT)) #correlation

model3 = smf.ols('np.log(AT) ~ Waist',data=wcat).fit()
model3.summary()
# predictions
pred_log = model3.predict(pd.DataFrame(wcat['Waist']))
pred_log
pred3 = np.exp(pred_log)
pred3
# printing the confidence interval
print(model3.conf_int(0.01)) # 99% confidence level
# residuals 
res3 = wcat.AT - pred3
res3
#rmse of third 
sqres3 = res3*res3
mse3 = np.mean(sqres3)
rmse3 = np.sqrt(mse3)
rmse3
# Out:
#                   0         1
# Intercept  0.130939  1.351102
# Waist      0.033684  0.046820
# 38.5290017580714
